# %%
from functionProcessing import processar_imagens

caminhos_imagens_OLI_C14 = [
    '/home/barcelos/Desktop/C/LC14/LC08_L1TP_215072_20141127_20200910_02_T1_B2.TIF',
    '/home/barcelos/Desktop/C/LC14/LC08_L1TP_215072_20141127_20200910_02_T1_B3.TIF',
    '/home/barcelos/Desktop/C/LC14/LC08_L1TP_215072_20141127_20200910_02_T1_B4.TIF',
    '/home/barcelos/Desktop/C/LC14/LC08_L1TP_215072_20141127_20200910_02_T1_B5.TIF'
]
caminhos_imagens_MODIS_C14 = [
    '/home/barcelos/Desktop/C/MC14/MC-14/2014-11-27-00:00_2014-11-27-23:59_MODIS_B1.TIF',
    '/home/barcelos/Desktop/C/MC14/MC-14/2014-11-27-00:00_2014-11-27-23:59_MODIS_B2.TIF',
    '/home/barcelos/Desktop/C/MC14/MC-14/2014-11-27-00:00_2014-11-27-23:59_MODIS_B3.TIF',
    '/home/barcelos/Desktop/C/MC14/MC-14/2014-11-27-00:00_2014-11-27-23:59_MODIS_B4.TIF'
]
diretorio_destino_pai_OLI_C14 = '/home/barcelos/Desktop/C/LC14/'
diretorio_destino_pai_MODIS_C14 = '/home/barcelos/Desktop/C/MC14'


caminhos_imagens_OLI_C15 = [
    '/home/barcelos/Desktop/C/LC15/LC08_L1TP_215072_20151130_20200908_02_T1_B2.TIF',
    '/home/barcelos/Desktop/C/LC15/LC08_L1TP_215072_20151130_20200908_02_T1_B3.TIF',
    '/home/barcelos/Desktop/C/LC15/LC08_L1TP_215072_20151130_20200908_02_T1_B4.TIF',
    '/home/barcelos/Desktop/C/LC15/LC08_L1TP_215072_20151130_20200908_02_T1_B5.TIF'
]
caminhos_imagens_MODIS_C15 = [
    '/home/barcelos/Desktop/C/MC15/MC15/2015-11-30-00:00_2015-11-30-23:59_MODIS_B1.TIF',
    '/home/barcelos/Desktop/C/MC15/MC15/2015-11-30-00:00_2015-11-30-23:59_MODIS_B2.TIF',
    '/home/barcelos/Desktop/C/MC15/MC15/2015-11-30-00:00_2015-11-30-23:59_MODIS_B3.TIF',
    '/home/barcelos/Desktop/C/MC15/MC15/2015-11-30-00:00_2015-11-30-23:59_MODIS_B4.TIF'
]
diretorio_destino_pai_OLI_C15 = '/home/barcelos/Desktop/C/LC15/'
diretorio_destino_pai_MODIS_C15 = '/home/barcelos/Desktop/C/MC15/'


caminhos_imagens_OLI_C16 = [
    '/home/barcelos/Desktop/C/LC16/LC08_L1TP_215072_20161218_20200905_02_T1_B2.TIF',
    '/home/barcelos/Desktop/C/LC16/LC08_L1TP_215072_20161218_20200905_02_T1_B3.TIF',
    '/home/barcelos/Desktop/C/LC16/LC08_L1TP_215072_20161218_20200905_02_T1_B4.TIF',
    '/home/barcelos/Desktop/C/LC16/LC08_L1TP_215072_20161218_20200905_02_T1_B5.TIF'
]
caminhos_imagens_MODIS_C16 = [
    '/home/barcelos/Desktop/C/MC16/MC16/2016-12-18-00:00_2016-12-18-23:59_MODIS_B1.TIF',
    '/home/barcelos/Desktop/C/MC16/MC16/2016-12-18-00:00_2016-12-18-23:59_MODIS_B2.TIF',
    '/home/barcelos/Desktop/C/MC16/MC16/2016-12-18-00:00_2016-12-18-23:59_MODIS_B3.TIF',
    '/home/barcelos/Desktop/C/MC16/MC16/2016-12-18-00:00_2016-12-18-23:59_MODIS_B4.TIF'
]
diretorio_destino_pai_OLI_C16 = '/home/barcelos/Desktop/C/LC16/'
diretorio_destino_pai_MODIS_C16 = '/home/barcelos/Desktop/C/MC16/'


caminhos_imagens_OLI_C22 = [
    '/home/barcelos/Desktop/C/LC22/LC09_L1TP_215072_20221211_20230318_02_T1_B2.TIF',
    '/home/barcelos/Desktop/C/LC22/LC09_L1TP_215072_20221211_20230318_02_T1_B3.TIF',
    '/home/barcelos/Desktop/C/LC22/LC09_L1TP_215072_20221211_20230318_02_T1_B4.TIF',
    '/home/barcelos/Desktop/C/LC22/LC09_L1TP_215072_20221211_20230318_02_T1_B5.TIF'
]
caminhos_imagens_MODIS_C22 = [
    '/home/barcelos/Desktop/C/MC22/MC22/2022-12-11-00:00_2022-12-11-23:59_MODIS_B1.TIF',
    '/home/barcelos/Desktop/C/MC22/MC22/2022-12-11-00:00_2022-12-11-23:59_MODIS_B2.TIF',
    '/home/barcelos/Desktop/C/MC22/MC22/2022-12-11-00:00_2022-12-11-23:59_MODIS_B3.TIF',
    '/home/barcelos/Desktop/C/MC22/MC22/2022-12-11-00:00_2022-12-11-23:59_MODIS_B4.TIF'
]
diretorio_destino_pai_OLI_C22 = '/home/barcelos/Desktop/C/LC22/'
diretorio_destino_pai_MODIS_C22 = '/home/barcelos/Desktop/C/MC22/'


caminho_shapefile_C = '/home/barcelos/Desktop/AOI/C/AOI4.shp'


print('----------- BEGIN CARAVELAS 14')
resultados_C14 = processar_imagens(caminhos_imagens_OLI_C14, caminhos_imagens_MODIS_C14, caminho_shapefile_C, diretorio_destino_pai_OLI_C14, diretorio_destino_pai_MODIS_C14)
print('----------- END CARAVELAS 14')


print('----------- BEGIN CARAVELAS 15')
resultados_C15 = processar_imagens(caminhos_imagens_OLI_C15, caminhos_imagens_MODIS_C15, caminho_shapefile_C, diretorio_destino_pai_OLI_C15, diretorio_destino_pai_MODIS_C15)
print('----------- END CARAVELAS 15')


print('----------- BEGIN CARAVELAS 16')
resultados_C16 = processar_imagens(caminhos_imagens_OLI_C16, caminhos_imagens_MODIS_C16, caminho_shapefile_C, diretorio_destino_pai_OLI_C16, diretorio_destino_pai_MODIS_C16)
print('----------- END CARAVELAS 16')

print('----------- BEGIN CARAVELAS 22')
resultados_C22 = processar_imagens(caminhos_imagens_OLI_C22, caminhos_imagens_MODIS_C22, caminho_shapefile_C, diretorio_destino_pai_OLI_C22, diretorio_destino_pai_MODIS_C22)
print('----------- END CARAVELAS 22')
# Out:
# ----------- BEGIN CARAVELAS 14
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC14/LL14CUTB2/LC08_L1TP_215072_20141127_20200910_02_T1_B2_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC14/LL14CUTB3/LC08_L1TP_215072_20141127_20200910_02_T1_B3_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC14/LL14CUTB4/LC08_L1TP_215072_20141127_20200910_02_T1_B4_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC14/LL14CUTB5/LC08_L1TP_215072_20141127_20200910_02_T1_B5_CUT.tif
# --------------- BEGIN NDWI OLI CALCULATION
# Max value in b3: 13124.0
# Min value in b3: 12149.0
# Max value in b5: 8165.0
# Min value in b5: 7409.0
# Number of elements in b3: 9898
# Number of elements in b5: 9898
# Number of elements with value 0 in b3: 198
# Number of elements with value 0 in b5: 198
# Max value in ndwi: 0.25389613561971763
# Min value in ndwi: 0.2117525874331682
# Gŕafico NDWI salvo em /home/barcelos/Desktop/C/LC14/ndwi_oli_graph_LC14.png
# --------------- END NDWI OLI CALCULATION
# --------------- BEGIN NDCI OLI CALCULATION
# Max value in b5: 8165.0
# Min value in b5: 7409.0
# Max value in b4: 11951.0
# Min value in b4: 9538.0
# Number of elements in b4: 9898
# Number of elements in b5: 9898
# Number of elements with value 0 in b4: 198
# Number of elements with value 0 in b5: 198
# Max value in ndci: -0.12073613878794982
# Min value in ndci: -0.19622203141572805
# Gŕafico NDCI salvo em /home/barcelos/Desktop/C/LC14/ndci_oli_graph_LC14.png
# --------------- END NDCI OLI CALCULATION
# --------------- BEGIN NDSSI OLI CALCULATION
# Max value in b2: 12725.0
# Min value in b2: 12037.0
# Max value in b5: 8165.0
# Min value in b5: 7409.0
# Number of elements in b5: 9898
# Number of elements in b2: 9898
# Number of elements with value 0 in b5: 198
# Number of elements with value 0 in b2: 198
# Max value in ndssi: 0.25342603788794843
# Min value in ndssi: 0.2019352946926009
# Gŕafico NDSSI salvo em /home/barcelos/Desktop/C/LC14/ndssi_oli_graph_LC14.png
# --------------- END NDSSI OLI CALCULATION
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC14/ML14CUTB1/2014-11-27-00:00_2014-11-27-23:59_MODIS_B1_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC14/ML14CUTB2/2014-11-27-00:00_2014-11-27-23:59_MODIS_B2_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC14/ML14CUTB3/2014-11-27-00:00_2014-11-27-23:59_MODIS_B3_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC14/ML14CUTB4/2014-11-27-00:00_2014-11-27-23:59_MODIS_B4_CUT.tif
# --------------- BEGIN NDWI MODIS CALCULATION
# Max value in b4: 9503.0
# Min value in b4: 7497.0
# Max value in b2: 3303.0
# Min value in b2: 1284.0
# Number of elements in b4: 49
# Number of elements in b2: 49
# Number of elements with value 0 in b4: 13
# Number of elements with value 0 in b2: 13
# Max value in ndwi: 0.7075503928937479
# Min value in ndwi: 0.45305514157973176
# Gŕafico NDWI salvo em /home/barcelos/Desktop/C/MC14/ndwi_modis_graph_MC14.png
# --------------- END NDWI MODIS CALCULATION
# --------------- BEGIN NDCI MODIS CALCULATION
# Max value in b1: 7320.0
# Min value in b1: 4666.0
# Max value in b2: 3303.0
# Min value in b2: 1284.0
# Number of elements in b2: 49
# Number of elements in b1: 49
# Number of elements with value 0 in b2: 13
# Number of elements with value 0 in b1: 13
# Max value in ndci: 0.5977733371395947
# Min value in ndci: 0.2779538747404088
# Gŕafico NDCI salvo em /home/barcelos/Desktop/C/MC14/ndci_modis_graph_MC14.png
# --------------- END NDCI MODIS CALCULATION
# --------------- BEGIN NDSSI MODIS CALCULATION
# Max value in b3: 6245.0
# Min value in b3: 4771.0
# Max value in b2: 3303.0
# Min value in b2: 1284.0
# Number of elements in b2: 49
# Number of elements in b3: 49
# Number of elements with value 0 in b2: 13
# Number of elements with value 0 in b3: 13
# Max value in ndssi: 0.5980591641884488
# Min value in ndssi: 0.2965605366840592
# Gŕafico NDSSI salvo em /home/barcelos/Desktop/C/MC14/ndssi_modis_graph_MC14.png
# --------------- END NDSSI MODIS CALCULATION
# ----------- END CARAVELAS 14
# ----------- BEGIN CARAVELAS 15
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC15/LL14CUTB2/LC08_L1TP_215072_20151130_20200908_02_T1_B2_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC15/LL14CUTB3/LC08_L1TP_215072_20151130_20200908_02_T1_B3_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC15/LL14CUTB4/LC08_L1TP_215072_20151130_20200908_02_T1_B4_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC15/LL14CUTB5/LC08_L1TP_215072_20151130_20200908_02_T1_B5_CUT.tif
# --------------- BEGIN NDWI OLI CALCULATION
# Max value in b3: 13142.0
# Min value in b3: 11866.0
# Max value in b5: 8110.0
# Min value in b5: 7111.0
# Number of elements in b3: 9898
# Number of elements in b5: 9898
# Number of elements with value 0 in b3: 198
# Number of elements with value 0 in b5: 198
# Max value in ndwi: 0.26842656819202554
# Min value in ndwi: 0.23025816249050873
# Gŕafico NDWI salvo em /home/barcelos/Desktop/C/LC15/ndwi_oli_graph_LC15.png
# --------------- END NDWI OLI CALCULATION
# --------------- BEGIN NDCI OLI CALCULATION
# Max value in b5: 8110.0
# Min value in b5: 7111.0
# Max value in b4: 11848.0
# Min value in b4: 9026.0
# Number of elements in b4: 9898
# Number of elements in b5: 9898
# Number of elements with value 0 in b4: 198
# Number of elements with value 0 in b5: 198
# Max value in ndci: -0.1157029860813048
# Min value in ndci: -0.19488321508105028
# Gŕafico NDCI salvo em /home/barcelos/Desktop/C/LC15/ndci_oli_graph_LC15.png
# --------------- END NDCI OLI CALCULATION
# --------------- BEGIN NDSSI OLI CALCULATION
# Max value in b2: 13078.0
# Min value in b2: 12582.0
# Max value in b5: 8110.0
# Min value in b5: 7111.0
# Number of elements in b5: 9898
# Number of elements in b2: 9898
# Number of elements with value 0 in b5: 198
# Number of elements with value 0 in b2: 198
# Max value in ndssi: 0.27812626467017404
# Min value in ndssi: 0.22413050758264363
# Gŕafico NDSSI salvo em /home/barcelos/Desktop/C/LC15/ndssi_oli_graph_LC15.png
# --------------- END NDSSI OLI CALCULATION
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC15/ML14CUTB1/2015-11-30-00:00_2015-11-30-23:59_MODIS_B1_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC15/ML14CUTB2/2015-11-30-00:00_2015-11-30-23:59_MODIS_B2_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC15/ML14CUTB3/2015-11-30-00:00_2015-11-30-23:59_MODIS_B3_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC15/ML14CUTB4/2015-11-30-00:00_2015-11-30-23:59_MODIS_B4_CUT.tif
# --------------- BEGIN NDWI MODIS CALCULATION
# Max value in b4: 10610.0
# Min value in b4: 8454.0
# Max value in b2: 2864.0
# Min value in b2: 1658.0
# Number of elements in b4: 49
# Number of elements in b2: 49
# Number of elements with value 0 in b4: 13
# Number of elements with value 0 in b2: 13
# Max value in ndwi: 0.6720727848101266
# Min value in ndwi: 0.572139303482587
# Gŕafico NDWI salvo em /home/barcelos/Desktop/C/MC15/ndwi_modis_graph_MC15.png
# --------------- END NDWI MODIS CALCULATION
# --------------- BEGIN NDCI MODIS CALCULATION
# Max value in b1: 8080.0
# Min value in b1: 5177.0
# Max value in b2: 2864.0
# Min value in b2: 1658.0
# Number of elements in b2: 49
# Number of elements in b1: 49
# Number of elements with value 0 in b2: 13
# Number of elements with value 0 in b1: 13
# Max value in ndci: 0.5763504891535517
# Min value in ndci: 0.41236834998649746
# Gŕafico NDCI salvo em /home/barcelos/Desktop/C/MC15/ndci_modis_graph_MC15.png
# --------------- END NDCI MODIS CALCULATION
# --------------- BEGIN NDSSI MODIS CALCULATION
# Max value in b3: 7746.0
# Min value in b3: 5394.0
# Max value in b2: 2864.0
# Min value in b2: 1658.0
# Number of elements in b2: 49
# Number of elements in b3: 49
# Number of elements with value 0 in b2: 13
# Number of elements with value 0 in b3: 13
# Max value in ndssi: 0.5845652718616888
# Min value in ndssi: 0.32433095998035844
# Gŕafico NDSSI salvo em /home/barcelos/Desktop/C/MC15/ndssi_modis_graph_MC15.png
# --------------- END NDSSI MODIS CALCULATION
# ----------- END CARAVELAS 15
# ----------- BEGIN CARAVELAS 16
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC16/LL14CUTB2/LC08_L1TP_215072_20161218_20200905_02_T1_B2_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC16/LL14CUTB3/LC08_L1TP_215072_20161218_20200905_02_T1_B3_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC16/LL14CUTB4/LC08_L1TP_215072_20161218_20200905_02_T1_B4_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC16/LL14CUTB5/LC08_L1TP_215072_20161218_20200905_02_T1_B5_CUT.tif
# --------------- BEGIN NDWI OLI CALCULATION
# Max value in b3: 13261.0
# Min value in b3: 12455.0
# Max value in b5: 8334.0
# Min value in b5: 6862.0
# Number of elements in b3: 9898
# Number of elements in b5: 9898
# Number of elements with value 0 in b3: 198
# Number of elements with value 0 in b5: 198
# Max value in ndwi: 0.2917159459042526
# Min value in ndwi: 0.22090305693185006
# Gŕafico NDWI salvo em /home/barcelos/Desktop/C/LC16/ndwi_oli_graph_LC16.png
# --------------- END NDWI OLI CALCULATION
# --------------- BEGIN NDCI OLI CALCULATION
# Max value in b5: 8334.0
# Min value in b5: 6862.0
# Max value in b4: 12419.0
# Min value in b4: 10049.0
# Number of elements in b4: 9898
# Number of elements in b5: 9898
# Number of elements with value 0 in b4: 198
# Number of elements with value 0 in b5: 198
# Max value in ndci: -0.16888433981576254
# Min value in ndci: -0.22369819341126462
# Gŕafico NDCI salvo em /home/barcelos/Desktop/C/LC16/ndci_oli_graph_LC16.png
# --------------- END NDCI OLI CALCULATION
# --------------- BEGIN NDSSI OLI CALCULATION
# Max value in b2: 12912.0
# Min value in b2: 12215.0
# Max value in b5: 8334.0
# Min value in b5: 6862.0
# Number of elements in b5: 9898
# Number of elements in b2: 9898
# Number of elements with value 0 in b5: 198
# Number of elements with value 0 in b2: 198
# Max value in ndssi: 0.28624921988766383
# Min value in ndssi: 0.20217527311227682
# Gŕafico NDSSI salvo em /home/barcelos/Desktop/C/LC16/ndssi_oli_graph_LC16.png
# --------------- END NDSSI OLI CALCULATION
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC16/ML14CUTB1/2016-12-18-00:00_2016-12-18-23:59_MODIS_B1_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC16/ML14CUTB2/2016-12-18-00:00_2016-12-18-23:59_MODIS_B2_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC16/ML14CUTB3/2016-12-18-00:00_2016-12-18-23:59_MODIS_B3_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC16/ML14CUTB4/2016-12-18-00:00_2016-12-18-23:59_MODIS_B4_CUT.tif
# --------------- BEGIN NDWI MODIS CALCULATION
# Max value in b4: 9693.0
# Min value in b4: 6514.0
# Max value in b2: 3362.0
# Min value in b2: 950.0
# Number of elements in b4: 49
# Number of elements in b2: 49
# Number of elements with value 0 in b4: 7
# Number of elements with value 0 in b2: 7
# Max value in ndwi: 0.7828323236941365
# Min value in ndwi: 0.3936333303273514
# Gŕafico NDWI salvo em /home/barcelos/Desktop/C/MC16/ndwi_modis_graph_MC16.png
# --------------- END NDWI MODIS CALCULATION
# --------------- BEGIN NDCI MODIS CALCULATION
# Max value in b1: 6298.0
# Min value in b1: 3165.0
# Max value in b2: 3362.0
# Min value in b2: 950.0
# Number of elements in b2: 49
# Number of elements in b1: 49
# Number of elements with value 0 in b2: 7
# Number of elements with value 0 in b1: 7
# Max value in ndci: 0.654419789014187
# Min value in ndci: 0.15208070617906683
# Gŕafico NDCI salvo em /home/barcelos/Desktop/C/MC16/ndci_modis_graph_MC16.png
# --------------- END NDCI MODIS CALCULATION
# --------------- BEGIN NDSSI MODIS CALCULATION
# Max value in b3: 7176.0
# Min value in b3: 4810.0
# Max value in b2: 3362.0
# Min value in b2: 950.0
# Number of elements in b2: 49
# Number of elements in b3: 49
# Number of elements with value 0 in b2: 7
# Number of elements with value 0 in b3: 7
# Max value in ndssi: 0.7195985832349469
# Min value in ndssi: 0.3191575536654516
# Gŕafico NDSSI salvo em /home/barcelos/Desktop/C/MC16/ndssi_modis_graph_MC16.png
# --------------- END NDSSI MODIS CALCULATION
# ----------- BEGIN CARAVELAS 22
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC22/LL14CUTB2/LC09_L1TP_215072_20221211_20230318_02_T1_B2_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC22/LL14CUTB3/LC09_L1TP_215072_20221211_20230318_02_T1_B3_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC22/LL14CUTB4/LC09_L1TP_215072_20221211_20230318_02_T1_B4_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/C/LC22/LL14CUTB5/LC09_L1TP_215072_20221211_20230318_02_T1_B5_CUT.tif
# --------------- BEGIN NDWI OLI CALCULATION
# Max value in b3: 12919.0
# Min value in b3: 10105.0
# Max value in b5: 9230.0
# Min value in b5: 7032.0
# Number of elements in b3: 9898
# Number of elements in b5: 9898
# Number of elements with value 0 in b3: 198
# Number of elements with value 0 in b5: 198
# Max value in ndwi: 0.24359241508647636
# Min value in ndwi: 0.15394593472733875
# Gŕafico NDWI salvo em /home/barcelos/Desktop/C/LC22/ndwi_oli_graph_LC22.png
# --------------- END NDWI OLI CALCULATION
# --------------- BEGIN NDCI OLI CALCULATION
# Max value in b5: 9230.0
# Min value in b5: 7032.0
# Max value in b4: 12576.0
# Min value in b4: 8492.0
# Number of elements in b4: 9898
# Number of elements in b5: 9898
# Number of elements with value 0 in b4: 198
# Number of elements with value 0 in b5: 198
# Max value in ndci: -0.07146517852058538
# Min value in ndci: -0.1950172276702889
# Gŕafico NDCI salvo em /home/barcelos/Desktop/C/LC22/ndci_oli_graph_LC22.png
# --------------- END NDCI OLI CALCULATION
# --------------- BEGIN NDSSI OLI CALCULATION
# Max value in b2: 12973.0
# Min value in b2: 11017.0
# Max value in b5: 9230.0
# Min value in b5: 7032.0
# Number of elements in b5: 9898
# Number of elements in b2: 9898
# Number of elements with value 0 in b5: 198
# Number of elements with value 0 in b2: 198
# Max value in ndssi: 0.23983037537301713
# Min value in ndssi: 0.15876777251184834
# Gŕafico NDSSI salvo em /home/barcelos/Desktop/C/LC22/ndssi_oli_graph_LC22.png
# --------------- END NDSSI OLI CALCULATION
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC22/ML14CUTB1/2022-12-11-00:00_2022-12-11-23:59_MODIS_B1_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC22/ML14CUTB2/2022-12-11-00:00_2022-12-11-23:59_MODIS_B2_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC22/ML14CUTB3/2022-12-11-00:00_2022-12-11-23:59_MODIS_B3_CUT.tif
# Imagem MODIS recortada salva em: /home/barcelos/Desktop/C/MC22/ML14CUTB4/2022-12-11-00:00_2022-12-11-23:59_MODIS_B4_CUT.tif
# --------------- BEGIN NDWI MODIS CALCULATION
# Max value in b4: 10813.0
# Min value in b4: 7805.0
# Max value in b2: 6612.0
# Min value in b2: 1317.0
# Number of elements in b4: 49
# Number of elements in b2: 49
# Number of elements with value 0 in b4: 7
# Number of elements with value 0 in b2: 7
# Max value in ndwi: 0.7452089797408287
# Min value in ndwi: 0.23040214165163242
# Gŕafico NDWI salvo em /home/barcelos/Desktop/C/MC22/ndwi_modis_graph_MC22.png
# --------------- END NDWI MODIS CALCULATION
# --------------- BEGIN NDCI MODIS CALCULATION
# Max value in b1: 11672.0
# Min value in b1: 4607.0
# Max value in b2: 6612.0
# Min value in b2: 1317.0
# Number of elements in b2: 49
# Number of elements in b1: 49
# Number of elements with value 0 in b2: 7
# Number of elements with value 0 in b1: 7
# Max value in ndci: 0.5943948259932245
# Min value in ndci: 0.07742584213172449
# Gŕafico NDCI salvo em /home/barcelos/Desktop/C/MC22/ndci_modis_graph_MC22.png
# --------------- END NDCI MODIS CALCULATION
# --------------- BEGIN NDSSI MODIS CALCULATION
# Max value in b3: 9063.0
# Min value in b3: 5086.0
# Max value in b2: 6612.0
# Min value in b2: 1317.0
# Number of elements in b2: 49
# Number of elements in b3: 49
# Number of elements with value 0 in b2: 7
# Number of elements with value 0 in b3: 7
# Max value in ndssi: 0.5942450225257957
# Min value in ndssi: 0.10495081700674742
# Gŕafico NDSSI salvo em /home/barcelos/Desktop/C/MC22/ndssi_modis_graph_MC22.png
# --------------- END NDSSI MODIS CALCULATION
# ----------- END CARAVELAS 22
