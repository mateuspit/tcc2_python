# %%
# !pip install scipy
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from functionProcessing import processar_imagens
from functionStatistics import calcular_estatisticas_indices
from functionStatisticsTex import calcular_estatisticas_indices_tex

caminhos_imagens_OLI_L14 = [
    '/home/barcelos/Desktop/L/LL14/LC08_L1TP_215074_20141229_20200910_02_T1_B2.TIF',
    '/home/barcelos/Desktop/L/LL14/LC08_L1TP_215074_20141229_20200910_02_T1_B3.TIF',
    '/home/barcelos/Desktop/L/LL14/LC08_L1TP_215074_20141229_20200910_02_T1_B4.TIF',
    '/home/barcelos/Desktop/L/LL14/LC08_L1TP_215074_20141229_20200910_02_T1_B5.TIF'
]
caminhos_imagens_MODIS_L14 = [
    '/home/barcelos/Desktop/L/ML14/ML14/2014-11-29-00:00_2014-11-29-23:59_MODIS_B1.TIF',
    '/home/barcelos/Desktop/L/ML14/ML14/2014-11-29-00:00_2014-11-29-23:59_MODIS_B2.TIF',
    '/home/barcelos/Desktop/L/ML14/ML14/2014-11-29-00:00_2014-11-29-23:59_MODIS_B3.TIF',
    '/home/barcelos/Desktop/L/ML14/ML14/2014-11-29-00:00_2014-11-29-23:59_MODIS_B4.TIF'
]
diretorio_destino_pai_OLI_L14 = '/home/barcelos/Desktop/L/LL14/'
diretorio_destino_pai_MODIS_L14 = '/home/barcelos/Desktop/L/ML14/'


caminhos_imagens_OLI_L15 = [
    '/home/barcelos/Desktop/L/LL15/LC08_L1TP_215074_20151216_20200908_02_T1_B2.TIF',
    '/home/barcelos/Desktop/L/LL15/LC08_L1TP_215074_20151216_20200908_02_T1_B3.TIF',
    '/home/barcelos/Desktop/L/LL15/LC08_L1TP_215074_20151216_20200908_02_T1_B4.TIF',
    '/home/barcelos/Desktop/L/LL15/LC08_L1TP_215074_20151216_20200908_02_T1_B5.TIF'
]
caminhos_imagens_MODIS_L15 = [
    '/home/barcelos/Desktop/L/ML15/ML15/2015-12-16-00:00_2015-12-16-23:59_MODIS_B1.TIF',
    '/home/barcelos/Desktop/L/ML15/ML15/2015-12-16-00:00_2015-12-16-23:59_MODIS_B2.TIF',
    '/home/barcelos/Desktop/L/ML15/ML15/2015-12-16-00:00_2015-12-16-23:59_MODIS_B3.TIF',
    '/home/barcelos/Desktop/L/ML15/ML15/2015-12-16-00:00_2015-12-16-23:59_MODIS_B4.TIF'
]
diretorio_destino_pai_OLI_L15 = '/home/barcelos/Desktop/L/LL15/'
diretorio_destino_pai_MODIS_L15 = '/home/barcelos/Desktop/L/ML15/'


caminhos_imagens_OLI_L16 = [
    '/home/barcelos/Desktop/L/LL16/LC08_L1TP_215074_20161218_20200905_02_T1_B2.TIF',
    '/home/barcelos/Desktop/L/LL16/LC08_L1TP_215074_20161218_20200905_02_T1_B3.TIF',
    '/home/barcelos/Desktop/L/LL16/LC08_L1TP_215074_20161218_20200905_02_T1_B4.TIF',
    '/home/barcelos/Desktop/L/LL16/LC08_L1TP_215074_20161218_20200905_02_T1_B5.TIF'
]
caminhos_imagens_MODIS_L16 = [
    '/home/barcelos/Desktop/L/ML16/ML16/2016-12-18-00:00_2016-12-18-23:59_MODIS_B1.TIF',
    '/home/barcelos/Desktop/L/ML16/ML16/2016-12-18-00:00_2016-12-18-23:59_MODIS_B2.TIF',
    '/home/barcelos/Desktop/L/ML16/ML16/2016-12-18-00:00_2016-12-18-23:59_MODIS_B3.TIF',
    '/home/barcelos/Desktop/L/ML16/ML16/2016-12-18-00:00_2016-12-18-23:59_MODIS_B4.TIF'
]
diretorio_destino_pai_OLI_L16 = '/home/barcelos/Desktop/L/LL16/'
diretorio_destino_pai_MODIS_L16 = '/home/barcelos/Desktop/L/ML16/'


caminhos_imagens_OLI_L22 = [
    '/home/barcelos/Desktop/L/LL22/LC09_L1TP_215074_20221211_20230318_02_T1_B2.TIF',
    '/home/barcelos/Desktop/L/LL22/LC09_L1TP_215074_20221211_20230318_02_T1_B3.TIF',
    '/home/barcelos/Desktop/L/LL22/LC09_L1TP_215074_20221211_20230318_02_T1_B4.TIF',
    '/home/barcelos/Desktop/L/LL22/LC09_L1TP_215074_20221211_20230318_02_T1_B5.TIF'
]
caminhos_imagens_MODIS_L22 = [
    '/home/barcelos/Desktop/L/ML22/ML22/2022-12-11-00:00_2022-12-11-23:59_MODIS_B1.TIF',
    '/home/barcelos/Desktop/L/ML22/ML22/2022-12-11-00:00_2022-12-11-23:59_MODIS_B2.TIF',
    '/home/barcelos/Desktop/L/ML22/ML22/2022-12-11-00:00_2022-12-11-23:59_MODIS_B3.TIF',
    '/home/barcelos/Desktop/L/ML22/ML22/2022-12-11-00:00_2022-12-11-23:59_MODIS_B4.TIF'
]
diretorio_destino_pai_OLI_L22 = '/home/barcelos/Desktop/L/LL22/'
diretorio_destino_pai_MODIS_L22 = '/home/barcelos/Desktop/L/ML22/'


caminho_shapefile_L = '/home/barcelos/Desktop/AOI/AOI2.shp'


#print('----------- BEGIN LINHARES 14')
#localAndYear = "LINHARES-2014"
#resultados_L14 = processar_imagens(caminhos_imagens_OLI_L14, caminhos_imagens_MODIS_L14, caminho_shapefile_L, diretorio_destino_pai_OLI_L14, diretorio_destino_pai_MODIS_L14)
#ndwi_OLI_L14 = resultados_L14[0]
#ndci_OLI_L14 = resultados_L14[1]
#ndssi_OLI_L14 = resultados_L14[2]
#ndwi_MODIS_L14 = resultados_L14[3]
#ndci_MODIS_L14 = resultados_L14[4]
#ndssi_MODIS_L14 = resultados_L14[5]
##statistics_L14_tex = calcular_estatisticas_indices_tex(ndwi_OLI_L14, ndci_OLI_L14, ndssi_OLI_L14, ndwi_MODIS_L14, ndci_MODIS_L14, ndssi_MODIS_L14, localAndYear)
#statistics_L14 = calcular_estatisticas_indices(ndwi_OLI_L14, ndci_OLI_L14, ndssi_OLI_L14, ndwi_MODIS_L14, ndci_MODIS_L14, ndssi_MODIS_L14, localAndYear)
## Imprimir o resultado em formato LaTeX
##print("\\begin{table}[]")
##print("\\centering")
##print("\\begin{tabular}{|l|lllll|}")
##print("\\hline")
##print(statistics_L14_tex)
##print("\\end{tabular}")
##print("\\end{table}")
#for resultado in statistics_L14:
#    print(f"Estatísticas para o índice {resultado['indice']}):")
#    print(f"  Média: {resultado['media']}")
#    print(f"  Mediana: {resultado['mediana']}")
#    print(f"  Moda: {resultado['moda']}")
#    print(f"  Desvio Padrão: {resultado['desvio_padrao']}")
#    print(f"  Variância: {resultado['variancia']}")
#    print("\n")




#print('----------- BEGIN LINHARES 15')
#localAndYear = "LINHARES-2015"
#resultados_L15 = processar_imagens(caminhos_imagens_OLI_L15, caminhos_imagens_MODIS_L15, caminho_shapefile_L, diretorio_destino_pai_OLI_L15, diretorio_destino_pai_MODIS_L15)
#ndwi_OLI_L15 = resultados_L15[0]
#ndci_OLI_L15 = resultados_L15[1]
#ndssi_OLI_L15 = resultados_L15[2]
#ndwi_MODIS_L15 = resultados_L15[3]
#ndci_MODIS_L15 = resultados_L15[4]
#ndssi_MODIS_L15 = resultados_L15[5]
##statistics_L15_tex = calcular_estatisticas_indices_tex(ndwi_OLI_L15, ndci_OLI_L15, ndssi_OLI_L15, ndwi_MODIS_L15, ndci_MODIS_L15, ndssi_MODIS_L15, localAndYear)
#statistics_L15 = calcular_estatisticas_indices(ndwi_OLI_L15, ndci_OLI_L15, ndssi_OLI_L15, ndwi_MODIS_L15, ndci_MODIS_L15, ndssi_MODIS_L15, localAndYear)
## Imprimir o resultado em formato LaTeX
##print("\\begin{table}[]")
##print("\\centering")
##print("\\begin{tabular}{|l|lllll|}")
##print("\\hline")
##print(statistics_L15_tex)
##print("\\end{tabular}")
##print("\\end{table}")
#for resultado in statistics_L15:
#    print(f"Estatísticas para o índice {resultado['indice']}):")
#    print(f"  Média: {resultado['media']}")
#    print(f"  Mediana: {resultado['mediana']}")
#    print(f"  Moda: {resultado['moda']}")
#    print(f"  Desvio Padrão: {resultado['desvio_padrao']}")
#    print(f"  Variância: {resultado['variancia']}")
#    print("\n")
#print('----------- END LINHARES 15')


#print('----------- BEGIN LINHARES 16')
#localAndYear = "LINHARES-2016"
#resultados_L16 = processar_imagens(caminhos_imagens_OLI_L16, caminhos_imagens_MODIS_L16, caminho_shapefile_L, diretorio_destino_pai_OLI_L16, diretorio_destino_pai_MODIS_L16)
#ndwi_OLI_L16 = resultados_L16[0]
#ndci_OLI_L16 = resultados_L16[1]
#ndssi_OLI_L16 = resultados_L16[2]
#ndwi_MODIS_L16 = resultados_L16[3]
#ndci_MODIS_L16 = resultados_L16[4]
#ndssi_MODIS_L16 = resultados_L16[5]
##statistics_L16_tex = calcular_estatisticas_indices_tex(ndwi_OLI_L16, ndci_OLI_L16, ndssi_OLI_L16, ndwi_MODIS_L16, ndci_MODIS_L16, ndssi_MODIS_L16, localAndYear)
#statistics_L16 = calcular_estatisticas_indices(ndwi_OLI_L16, ndci_OLI_L16, ndssi_OLI_L16, ndwi_MODIS_L16, ndci_MODIS_L16, ndssi_MODIS_L16, localAndYear)
### Imprimir o resultado em formato LaTeX
##print("\\begin{table}[]")
##print("\\centering")
##print("\\begin{tabular}{|l|lllll|}")
##print("\\hline")
##print(statistics_L16_tex)
##print("\\end{tabular}")
##print("\\end{table}")
#for resultado in statistics_L16:
#    print(f"Estatísticas para o índice {resultado['indice']}):")
#    print(f"  Média: {resultado['media']}")
#    print(f"  Mediana: {resultado['mediana']}")
#    print(f"  Moda: {resultado['moda']}")
#    print(f"  Desvio Padrão: {resultado['desvio_padrao']}")
#    print(f"  Variância: {resultado['variancia']}")
#    print("\n")
#print('----------- END LINHARES 16')

print('----------- BEGIN LINHARES 22')
localAndYear = "LINHARES-2022"
resultados_L22 = processar_imagens(caminhos_imagens_OLI_L22, caminhos_imagens_MODIS_L22, caminho_shapefile_L, diretorio_destino_pai_OLI_L22, diretorio_destino_pai_MODIS_L22)
#ndwi_OLI_L22 = resultados_L22[0]
#ndci_OLI_L22 = resultados_L22[1]
#ndssi_OLI_L22 = resultados_L22[2]
#ndwi_MODIS_L22 = resultados_L22[3]
#ndci_MODIS_L22 = resultados_L22[4]
#ndssi_MODIS_L22 = resultados_L22[5]
#statistics_L22_tex = calcular_estatisticas_indices_tex(ndwi_OLI_L22, ndci_OLI_L22, ndssi_OLI_L22, ndwi_MODIS_L22, ndci_MODIS_L22, ndssi_MODIS_L22, localAndYear)
statistics_L22 = calcular_estatisticas_indices(ndwi_OLI_L22, ndci_OLI_L22, ndssi_OLI_L22, ndwi_MODIS_L22, ndci_MODIS_L22, ndssi_MODIS_L22, localAndYear)
### Imprimir o resultado em formato LaTeX
#print("\\begin{table}[]")
#print("\\centering")
#print("\\begin{tabular}{|l|lllll|}")
#print("\\hline")
#print(statistics_L22_tex)
#print("\\end{tabular}")
#print("\\end{table}")
for resultado in statistics_L22:
    print(f"Estatísticas para o índice {resultado['indice']}):")
    print(f"  Média: {resultado['media']}")
    print(f"  Mediana: {resultado['mediana']}")
    print(f"  Moda: {resultado['moda']}")
    print(f"  Desvio Padrão: {resultado['desvio_padrao']}")
    print(f"  Variância: {resultado['variancia']}")
    print("\n")
print('----------- END LINHARES 22')
# Out:
# ----------- BEGIN LINHARES 22
# Imagem OLI recortada salva em: /home/barcelos/Desktop/L/LL22/LL14CUTB2/LC09_L1TP_215074_20221211_20230318_02_T1_B2_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/L/LL22/LL14CUTB3/LC09_L1TP_215074_20221211_20230318_02_T1_B3_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/L/LL22/LL14CUTB4/LC09_L1TP_215074_20221211_20230318_02_T1_B4_CUT.tif
# Imagem OLI recortada salva em: /home/barcelos/Desktop/L/LL22/LL14CUTB5/LC09_L1TP_215074_20221211_20230318_02_T1_B5_CUT.tif
# --------------- BEGIN NDWI OLI CALCULATION
# Max value in b3: 12851.0
# Min value in b3: 9677.0
# Max value in b5: 8707.0
# Min value in b5: 6223.0
# Number of elements in b3: 9595
# Number of elements in b5: 9595
# Number of elements with value 0 in b3: 205
# Number of elements with value 0 in b5: 205
# Max value in ndwi: 0.2846628422989501
# Min value in ndwi: 0.1827099075421223
# Gŕafico NDWI OLI salvo em /home/barcelos/Desktop/L/LL22/ndwi_oli_graph_LL22.png
# ...
